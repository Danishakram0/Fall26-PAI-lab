# %%
! pip install flask opencv-python numpy
# Out:
# ...
#   Using cached opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB 262.6 kB/s eta 0:00:47
#    ---------------------------------------- 0.1/12.3 MB 328.2 kB/s eta 0:00:38
#    ---------------------------------------- 0.1/12.3 MB 353.1 kB/s eta 0:00:35
#    ---------------------------------------- 0.1/12.3 MB 348.6 kB/s eta 0:00:36
#    ---------------------------------------- 0.1/12.3 MB 364.4 kB/s eta 0:00:34
# ...

# %%
! pip install flask
